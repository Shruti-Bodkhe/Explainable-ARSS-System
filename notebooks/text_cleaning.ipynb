# %%
import nltk
nltk.data.path.append("C:/Users/shruti/nltk_data")

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\shruti/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shruti/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shruti/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
print(stopwords.words('english')[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
import pandas as pd
import re
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv("E:\\Explainable_ARSS_Project\\dataset\\resume_text_dataset.csv")

print(df.head())
print(df.shape)
# Out:
#     resume_file                                        resume_text
# 0  10030015.pdf  ENGINEERING LAB TECHNICIAN\nCareer Focus\nMy m...
# 1  10070224.pdf  PUBLIC RELATIONS DIRECTOR\nSummary\nTalented P...
# 2  10176815.pdf  AVIATION ELECTRONICS TECHNICIAN\nSummary\nSeek...
# 3  10235429.pdf  FITNESS INSTRUCTOR\nProfessional Summary\nDyna...
# 4  10281555.pdf  CONSTRUCTION SITE MANAGER\nSummary\n\nsupervis...
# (300, 2)

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_resume(text):
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # Tokenization
    words = word_tokenize(text)
    
    # Remove stopwords
    words = [word for word in words if word not in stop_words]
    
    # Lemmatization
    words = [lemmatizer.lemmatize(word) for word in words]
    
    return " ".join(words)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\shruti/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shruti/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shruti/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\shruti/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
print(nltk.data.path)

import nltk

nltk.download('punkt', download_dir='C:/Users/shruti/nltk_data')
nltk.download('stopwords', download_dir='C:/Users/shruti/nltk_data')
nltk.download('wordnet', download_dir='C:/Users/shruti/nltk_data')
nltk.download('omw-1.4', download_dir='C:/Users/shruti/nltk_data')

import nltk
nltk.data.path.append('C:/Users/shruti/nltk_data')
# Out:
# ['C:\\Users\\shruti/nltk_data', 'e:\\Explainable_ARSS_Project\\arss_env\\nltk_data', 'e:\\Explainable_ARSS_Project\\arss_env\\share\\nltk_data', 'e:\\Explainable_ARSS_Project\\arss_env\\lib\\nltk_data', 'C:\\Users\\shruti\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']
# [nltk_data] Downloading package punkt to C:/Users/shruti/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:/Users/shruti/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:/Users/shruti/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:/Users/shruti/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

print(stopwords.words('english')[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
import traceback

try:
    df["cleaned_text"] = df["resume_text"].apply(clean_resume)
except Exception:
    traceback.print_exc()

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\shruti/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\shruti/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize

print(word_tokenize("Machine learning is amazing"))
# Out:
# ['Machine', 'learning', 'is', 'amazing']

# %%
df["cleaned_text"] = df["resume_text"].apply(clean_resume)

# %%
df["cleaned_text"] = df["resume_text"].apply(clean_resume)

# %%
print("ORIGINAL TEXT:\n")
print(df["resume_text"].iloc[0][:500])

print("\n\nCLEANED TEXT:\n")
print(df["cleaned_text"].iloc[0][:500])
# Out:
# ORIGINAL TEXT:
#
# ENGINEERING LAB TECHNICIAN
# Career Focus
# My main objective in seeking employment with Triumph Actuation Systems Inc. is to work in a professional atmosphere where I can utilize my
# skills and continue to gain experience in the aerospace industry to advance in my career.
# Professional Experience
# Engineering Lab Technician Oct 2016 to Current
# Company Name ï¼​ City , State
#
# Responsible for testing various seat structures to meet specific certification requirements. Â
# Maintain and calibrate test inst
#
#
# CLEANED TEXT:
#
# ...

# %%
df.to_csv("../dataset/resume_cleaned_dataset.csv", index=False)

# %%
print(skills_df.columns)
# Out:
# Index(['Skill_name', 'Category', 'Skill_type'], dtype='object')

# %%
# Load Master Skill Dataset
import pandas as pd

# Load Excel file
skills_df = pd.read_excel("../dataset/skills_master.xlsx")

# Standardize column names (Professional Practice)
skills_df.columns = skills_df.columns.str.strip().str.title().str.replace(" ", "_")

# Convert skills into lowercase list
skill_list = skills_df["Skill_Name"].str.lower().tolist()

# Display results
print("Total Skills Loaded:", len(skill_list))
print("\nSample Skills:")
print(skill_list[:10])
# Out:
# Total Skills Loaded: 127
#
# Sample Skills:
# [nan, 'python', 'java', 'c', 'c++', 'c#', 'r', 'javascript', 'typescript', 'go']
